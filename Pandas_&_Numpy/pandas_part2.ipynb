# %%
import pandas as pd

# %%
df=pd.read_csv('datasets/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv', delimiter=',')

# %%
column_mapping = {
    'Timestamp': 'timestamp',
    'How old are you?': 'age',
    'What industry do you work in?': 'industry',
    'Job title': 'job_title',
    'If your job title needs additional context, please clarify here:': 'job_title_context',
    "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": 'annual_salary',
    'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.': 'additional_compensation',
    'Please indicate the currency': 'currency',
    'If "Other," please indicate the currency here: ': 'other_currency',
    'If your income needs additional context, please provide it here:': 'income_context',
    'What country do you work in?': 'country',
    "If you're in the U.S., what state do you work in?": 'state',
    'What city do you work in?': 'city',
    'How many years of professional work experience do you have overall?': 'total_experience_years',
    'How many years of professional work experience do you have in your field?': 'field_experience_years',
    'What is your highest level of education completed?': 'education_level',
    'What is your gender?': 'gender',
    'What is your race? (Choose all that apply.)': 'race'
}

df.rename(columns=column_mapping, inplace=True)

# %%
df.sample(5)
# Out:
#                 timestamp    age                         industry  \
# 24763   5/5/2021 19:11:47  25-34    Accounting, Banking & Finance
# 24867   5/5/2021 21:03:36  55-64                    Entertainment
# 25423   5/6/2021 15:03:34  35-44                           Retail
# 13478  4/28/2021 12:51:46  35-44  Library and Information Science
# 6692   4/27/2021 14:02:21  25-34    Accounting, Banking & Finance
#
#                     job_title                  job_title_context  \
# 24763       Senior Bookkeeper                                NaN
# 24867   Co-Executive Producer                 (Senior TV Writer)
# 25423          Store manager                                 NaN
# 13478  Makerspace Coordinator  Librarian in charge of makerspace
# 6692                  Payroll                                NaN
#
#       annual_salary  additional_compensation currency other_currency  \
# 24763         47250                   4000.0      USD            NaN
# 24867        200000                  50000.0      CAD            NaN
# 25423         52000                  15000.0      USD            NaN
# 13478        46,183                      NaN      USD            NaN
# 6692         57,000                   2000.0      USD            NaN
#
#                                           income_context        country  \
# 24763                                                NaN  United States
# 24867  Jobs usually can run 8-26 weeks, rarely more, ...             US
# 25423                                                NaN           USA
# 13478                                                NaN            USA
# 6692                                                 NaN            USA
#
#                 state         city total_experience_years  \
# 24763        Maryland    Frederick              5-7 years
# 24867      California  Los Angeles          31 - 40 years
# 25423        Michigan     Rockford         1 year or less
# 13478  South Carolina     Columbia          11 - 20 years
# 6692         Colorado         Mead           8 - 10 years
#
#       field_experience_years  education_level gender   race
# 24763              5-7 years   College degree  Woman  White
# 24867          31 - 40 years   College degree  Woman  White
# 25423           8 - 10 years      High School    Man  White
# 13478              5-7 years  Master's degree  Woman  White
# 6692             2 - 4 years   College degree  Woman  White

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28223 entries, 0 to 28222
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                28223 non-null  str
#  1   age                      28223 non-null  str
#  2   industry                 28137 non-null  str
#  3   job_title                28218 non-null  str
#  4   job_title_context        7293 non-null   str
#  5   annual_salary            28223 non-null  str
#  6   additional_compensation  20849 non-null  float64
#  7   currency                 28223 non-null  str
#  8   other_currency           224 non-null    str
#  9   income_context           3053 non-null   str
#  10  country                  28221 non-null  str
#  11  state                    23147 non-null  str
#  12  city                     28138 non-null  str
#  13  total_experience_years   28223 non-null  str
#  14  field_experience_years   28223 non-null  str
#  15  education_level          27982 non-null  str
#  16  gender                   28037 non-null  str
#  17  race                     28026 non-null  str
# dtypes: float64(1), str(17)
# memory usage: 3.9 MB

# %%
df.nunique()
# Out:
# timestamp                  25441
# age                            7
# industry                    1225
# job_title                  14433
# job_title_context           7029
# annual_salary               4332
# additional_compensation      849
# currency                      11
# other_currency               130
# income_context              2988
# country                      390
# state                        138
# city                        4875
# total_experience_years         8
# field_experience_years         8
# education_level                6
# gender                         5
# race                          52
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp                      0
# age                            0
# industry                      86
# job_title                      5
# job_title_context          20930
# annual_salary                  0
# additional_compensation     7374
# currency                       0
# other_currency             27999
# income_context             25170
# country                        2
# state                       5076
# city                          85
# total_experience_years         0
# field_experience_years         0
# education_level              241
# gender                       186
# race                         197
# dtype: int64

# %%
# Get unique race values from white rows
unique_races = df[df['race'].str.contains('white', case=False)]['race'].unique()
print(unique_races)
# Output: ['White' 'white']
# Out:
# <StringArray>
# [                                                                                                                                                                                                                       'White',
#                                                                                                                                                                                    'Hispanic, Latino, or Spanish origin, White',
#                                                                                                                                                                                                'Asian or Asian American, White',
#                                                                                                                                                'Hispanic, Latino, or Spanish origin, Middle Eastern or Northern African, White',
#                                                                                                                                                                                              'Black or African American, White',
#                                                                                                                                                         'Black or African American, Hispanic, Latino, or Spanish origin, White',
#                                                                                                                                                                                       'Native American or Alaska Native, White',
#                                                                                                                        'Black or African American, Middle Eastern or Northern African, Native American or Alaska Native, White',
#                                                                                                                                                                 'White, Another option not listed here or prefer not to answer',
#                                                                                                                                                            'Black or African American, Native American or Alaska Native, White',
#                                                                                                                                                                                     'Middle Eastern or Northern African, White',
#                                                                                                                                                                     'Asian or Asian American, Black or African American, White',
#                                                                                                                                                           'Asian or Asian American, Hispanic, Latino, or Spanish origin, White',
#                                                                                                                               'Native American or Alaska Native, White, Another option not listed here or prefer not to answer',
#                                                                                                                                                              'Asian or Asian American, Native American or Alaska Native, White',
#                                                                                                                                                          'Black or African American, Middle Eastern or Northern African, White',
#                                                                                                                       'Black or African American, Hispanic, Latino, or Spanish origin, Native American or Alaska Native, White',
#                                                                                                                                        'Asian or Asian American, White, Another option not listed here or prefer not to answer',
#                                                                                                                         'Asian or Asian American, Hispanic, Latino, or Spanish origin, Native American or Alaska Native, White',
#                                                                                                                                                  'Hispanic, Latino, or Spanish origin, Native American or Alaska Native, White',
#                                                                                                                             'Middle Eastern or Northern African, White, Another option not listed here or prefer not to answer',
#                                                                                                                            'Hispanic, Latino, or Spanish origin, White, Another option not listed here or prefer not to answer',
#                                                                                                                                   'Asian or Asian American, Black or African American, Native American or Alaska Native, White',
#                                                                                                                                                   'Middle Eastern or Northern African, Native American or Alaska Native, White',
#                                                                                                                                                            'Asian or Asian American, Middle Eastern or Northern African, White',
#                                                                                                   'Asian or Asian American, Hispanic, Latino, or Spanish origin, White, Another option not listed here or prefer not to answer',
#  'Asian or Asian American, Black or African American, Hispanic, Latino, or Spanish origin, Middle Eastern or Northern African, Native American or Alaska Native, White, Another option not listed here or prefer not to answer',
#                                                          'Asian or Asian American, Black or African American, Hispanic, Latino, or Spanish origin, Middle Eastern or Northern African, Native American or Alaska Native, White']
# Length: 28, dtype: str

# %%
df.query('race == "White"').count()
# Out:
# timestamp                  23274
# age                        23274
# industry                   23218
# job_title                  23273
# job_title_context           6205
# annual_salary              23274
# additional_compensation    17416
# currency                   23274
# other_currency               106
# income_context              2507
# country                    23274
# state                      19118
# city                       23208
# total_experience_years     23274
# field_experience_years     23274
# education_level            23143
# gender                     23188
# race                       23274
# dtype: int64
