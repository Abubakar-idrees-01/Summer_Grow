# %%
print("hellow")
# Out:
# hellow

# %%
import pandas as pd

# %%
df=pd.read_xml("datasets/311_ServiceRequest_2020-present_DataDictionary_Updated_2025.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.read_xml("datasets/311_ServiceRequest_2020-present_DataDictionary_Updated_2025.xlsx")
#       2 df.head()
#
# File /media/abubakar/study material/Summer_Grow/ai-env/lib/python3.12/site-packages/pandas/io/xml.py:1138, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, dtype_backend)
#     860 r"""
#     861 Read XML document into a :class:`~pandas.DataFrame` object.
#     862
#    (...)   1134 1      1  <NA>  4.5  False  b 2019-12-31
#    1135 """
#    1136 check_dtype_backend(dtype_backend)
# -> 1138 return _parse(
#    1139     path_or_buffer=path_or_buffer,
#    1140     xpath=xpath,
#    1141     namespaces=namespaces,
#    1142     elems_only=elems_only,
# ...
