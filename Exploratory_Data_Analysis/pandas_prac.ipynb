# %%
ls
# Out:
# datasets/  pandas_prac.ipynb*

# %%
import pandas as pd

df=pd.read_csv('datasets/wine+quality/winequality-white.csv', delimiter=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df["quality"].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3345            6.8              0.18         0.24             9.8      0.058
# 316             6.8              0.25         0.34             4.7      0.031
# 4632            6.3              0.30         0.91             8.2      0.034
# 4242            5.9              0.22         0.29             4.2      0.037
# 1963            7.4              0.32         0.55            16.6      0.056
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3345                 64.0                 188.0  0.99520  3.13       0.51
# 316                  34.0                 134.0  0.99270  3.21       0.38
# 4632                 50.0                 199.0  0.99394  3.39       0.49
# 4242                 69.0                 144.0  0.99214  3.13       0.74
# 1963                 53.0                 238.0  1.00170  2.96       0.58
#
#       alcohol  quality
# 3345     10.6        6
# ...

# %%
df[['fixed acidity', 'volatile acidity', 'citric acid',"quality"]].head()
# Out:
#    fixed acidity  volatile acidity  citric acid  quality
# 0            7.0              0.27         0.36        6
# 1            6.3              0.30         0.34        6
# 2            8.1              0.28         0.40        6
# 3            7.2              0.23         0.32        6
# 4            7.2              0.23         0.32        6

# %%
df.loc[1 : 5 , ['fixed acidity', 'volatile acidity', 'citric acid',"quality"]]
# Out:
#    fixed acidity  volatile acidity  citric acid  quality
# 1            6.3              0.30         0.34        6
# 2            8.1              0.28         0.40        6
# 3            7.2              0.23         0.32        6
# 4            7.2              0.23         0.32        6
# 5            8.1              0.28         0.40        6

# %%
df.iloc[1 : 5 ,0:5]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058

# %%
df[(df['quality']<5) & (df['fixed acidity']<6)].head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 115            5.5             0.485         0.00             1.5      0.065
# 204            5.8             0.280         0.35             2.3      0.053
# 250            5.9             0.210         0.28             4.6      0.053
# 253            5.8             0.240         0.44             3.5      0.029
# 259            5.8             0.360         0.38             0.9      0.037
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 115                  8.0                 103.0   0.9940  3.63       0.40
# 204                 36.0                 114.0   0.9924  3.28       0.50
# 250                 40.0                 199.0   0.9964  3.72       0.70
# 253                  5.0                 109.0   0.9913  3.53       0.43
# 259                  3.0                  75.0   0.9904  3.28       0.34
#
#      alcohol  quality
# 115      9.7        4
# ...

# %%
newdf=df.sort_values("quality", ascending=False)
newdf
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 827             7.4             0.240         0.36             2.0      0.031
# 820             6.6             0.360         0.29             1.6      0.021
# 1605            7.1             0.260         0.49             2.2      0.032
# 876             6.9             0.360         0.34             4.2      0.018
# 774             9.1             0.270         0.45            10.6      0.035
# ...             ...               ...          ...             ...        ...
# 2373            7.6             0.480         0.37             1.2      0.034
# 3409            6.2             0.230         0.35             0.7      0.051
# 3265            4.2             0.215         0.23             5.1      0.041
# 3087            6.1             0.200         0.34             9.5      0.041
# 3307            9.4             0.240         0.29             8.5      0.037
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(937)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.rename(columns={'fixed acidity':'fixed_acidity', 'volatile acidity':'volatile_acidity', 'citric acid':'citric_acid' , "residual sugar":"residual_sugar" , "free sulfur dioxide":"free_sulfur_dioxide" , "total sulfur dioxide":"total_sulfur_dioxide" ,"total sulfur dioxide":"total_sulfur_dioxide"}, inplace=True)

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='str')

# %%
df["new_quality"]=df["quality"].apply(lambda x: "good" if x>=7 else "bad")
df[df["new_quality"]=="good"].count()
# Out:
# fixed_acidity           825
# volatile_acidity        825
# citric_acid             825
# residual_sugar          825
# chlorides               825
# free_sulfur_dioxide     825
# total_sulfur_dioxide    825
# density                 825
# pH                      825
# sulphates               825
# alcohol                 825
# quality                 825
# new_quality             825
# dtype: int64

# %%
df.drop("new_quality", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3961 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         3961 non-null   float64
#  1   volatile_acidity      3961 non-null   float64
#  2   citric_acid           3961 non-null   float64
#  3   residual_sugar        3961 non-null   float64
#  4   chlorides             3961 non-null   float64
#  5   free_sulfur_dioxide   3961 non-null   float64
#  6   total_sulfur_dioxide  3961 non-null   float64
#  7   density               3961 non-null   float64
#  8   pH                    3961 non-null   float64
#  9   sulphates             3961 non-null   float64
#  10  alcohol               3961 non-null   float64
#  11  quality               3961 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 402.3 KB

# %%
df.groupby("quality").mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.139869          0.382157     0.305229        4.499346
# 5             6.921745          0.303306     0.335957        6.941532
# 6             6.819435          0.261630     0.338227        5.959787
# 7             6.701089          0.265363     0.327358        4.523875
# 8             6.609924          0.286794     0.335038        5.056489
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050059            23.127451            124.127451  0.994199
# 5         0.052323            36.002979            150.099574  0.995072
# 6         0.045178            35.308166            136.460850  0.993722
# ...

# %%
df.pivot_table(index="quality", values=["fixed_acidity", "volatile_acidity", "citric_acid"], aggfunc="std")
# Out:
#          citric_acid  fixed_acidity  volatile_acidity
# quality
# 3           0.081460       1.724743          0.140827
# 4           0.163940       1.101574          0.176209
# 5           0.140859       0.862071          0.103415
# 6           0.120617       0.853331          0.089767
# 7           0.082185       0.775123          0.092231
# 8           0.087217       0.822646          0.103862
# 9           0.082037       0.983362          0.057619

# %%
df["quality"] = df["quality"].apply(lambda x: x-2)

# %%
df["quality"].value_counts()
# Out:
# quality
# 4    1788
# 3    1175
# 5     689
# 2     153
# 6     131
# 1      20
# 7       5
# Name: count, dtype: int64

# %%
df.pivot_table(index="quality", values=["fixed_acidity", "volatile_acidity", "citric_acid"], aggfunc="max")
# Out:
#          citric_acid  fixed_acidity  volatile_acidity
# quality
# 1               0.47           11.8             0.640
# 2               0.88           10.2             1.100
# 3               1.00           10.3             0.905
# 4               1.66           14.2             0.965
# 5               0.74            9.2             0.760
# 6               0.74            8.2             0.660
# 7               0.49            9.1             0.360

# %%
df.corr(numeric_only=True)
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.019214     0.298959
# volatile_acidity          -0.019214          1.000000    -0.163228
# citric_acid                0.298959         -0.163228     1.000000
# residual_sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free_sulfur_dioxide       -0.058396         -0.102471     0.091681
# total_sulfur_dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                        -0.431274         -0.046954    -0.183015
# sulphates                 -0.017453         -0.021150     0.049442
# alcohol                   -0.110788          0.046815    -0.076514
# quality                   -0.124636         -0.190678     0.007065
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
df.agg({
    "fixed_acidity": ["mean", "median", "max" , "min"],
    "residual_sugar": ["mean", "median", "max" , "min"]
})
# Out:
#         fixed_acidity  residual_sugar
# mean         6.839346        5.914819
# median       6.800000        4.700000
# max         14.200000       65.800000
# min          3.800000        0.600000

# %%
df.to_csv("datasets/wine+quality/winequality-white-edited.csv", index=False)
